# %%
# 매우 작은 브라우저로 웹사이트의 내용과 정보를 불러 올 수 있다
import requests

# 리퀘스트로 가져온 웹사이트의 내용과 정보를 불러올 수 있다
from bs4 import BeautifulSoup

#대량 데이터 처리시 진행상황을 알 수 있다
from tqdm import tqdm, trange 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams.update({'font.size': 20})
# Window 의 한글 폰트 설정
plt.rc('font',family='Malgun Gothic')
# %matplotlib inline

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2019.9.11)

# %%
#url sort = p 인기순 

def get_suggestion_list(singers, pages):
    suggestion_list = []
    suggestion_album = []
    singer_list = [] 
    for singer in singers: 
        for page in range(pages): 
            base_url = requests.get("https://music.bugs.co.kr/search/track?q=" + singer+'&flac_only=false&target=ARTIST_TRACK_ALBUM&page='+str(page+1)+'&sort=P')
            if base_url.status_code == 200 : 
                soup = BeautifulSoup(base_url.text, 'html.parser', from_encoding="utf8")
                tags = soup.select('#DEFAULT0 > table > tbody')[0].find_all('tr')
                for tag in tags:
                    suggestion_list.append('https://music.bugs.co.kr/track/'+tag['trackid'])
                    suggestion_album.append('https://music.bugs.co.kr/album/'+tag['albumid'])
                    singer_list.append(singer)
            
    return suggestion_list, suggestion_album, singer_list

# %%
get_suggestion_list("Lauv",1)
# Out:
# (['https://music.bugs.co.kr/track/31705498',
#   'https://music.bugs.co.kr/track/66966',
#   'https://music.bugs.co.kr/track/85854',
#   'https://music.bugs.co.kr/track/82633',
#   'https://music.bugs.co.kr/track/5598004',
#   'https://music.bugs.co.kr/track/33273',
#   'https://music.bugs.co.kr/track/27654',
#   'https://music.bugs.co.kr/track/33268',
#   'https://music.bugs.co.kr/track/33271',
#   'https://music.bugs.co.kr/track/30370362',
#   'https://music.bugs.co.kr/track/1765251',
#   'https://music.bugs.co.kr/track/2960147',
#   'https://music.bugs.co.kr/track/5763702',
#   'https://music.bugs.co.kr/track/489233',
#   'https://music.bugs.co.kr/track/80301392',
#   'https://music.bugs.co.kr/track/66964',
#   'https://music.bugs.co.kr/track/5463985',
#   'https://music.bugs.co.kr/track/80097256',
#   'https://music.bugs.co.kr/track/80282596',
#   'https://music.bugs.co.kr/track/31068174',
#   'https://music.bugs.co.kr/track/5005963',
#   'https://music.bugs.co.kr/track/30653655',
#   'https://music.bugs.co.kr/track/1702982',
#   'https://music.bugs.co.kr/track/1684031',
#   'https://music.bugs.co.kr/track/30830454',
#   'https://music.bugs.co.kr/track/7712',
#   'https://music.bugs.co.kr/track/21372112',
#   'https://music.bugs.co.kr/track/7711',
#   'https://music.bugs.co.kr/track/104276',
#   'https://music.bugs.co.kr/track/4410205',
#   'https://music.bugs.co.kr/track/31503915',
#   'https://music.bugs.co.kr/track/3414999',
#   'https://music.bugs.co.kr/track/80035205',
#   'https://music.bugs.co.kr/track/1712405',
#   'https://music.bugs.co.kr/track/31503916',
#   'https://music.bugs.co.kr/track/61819',
#   'https://music.bugs.co.kr/track/83790',
#   'https://music.bugs.co.kr/track/80178162',
#   'https://music.bugs.co.kr/track/38083',
#   'https://music.bugs.co.kr/track/5041022',
#   'https://music.bugs.co.kr/track/82639',
#   'https://music.bugs.co.kr/track/5842327',
#   'https://music.bugs.co.kr/track/30489218',
#   'https://music.bugs.co.kr/track/5730202',
#   'https://music.bugs.co.kr/track/105690',
#   'https://music.bugs.co.kr/track/31129210',
#   'https://music.bugs.co.kr/track/3086282',
#   'https://music.bugs.co.kr/track/30519001',
#   'https://music.bugs.co.kr/track/31503918',
#   'https://music.bugs.co.kr/track/450316',
#   'https://music.bugs.co.kr/track/5812157',
#   'https://music.bugs.co.kr/track/31868912',
#   'https://music.bugs.co.kr/track/30609286',
#   'https://music.bugs.co.kr/track/5647368',
#   'https://music.bugs.co.kr/track/4927752',
#   'https://music.bugs.co.kr/track/30404027',
#   'https://music.bugs.co.kr/track/5763622',
#   'https://music.bugs.co.kr/track/5545093',
#   'https://music.bugs.co.kr/track/31587161',
#   'https://music.bugs.co.kr/track/30850084',
#   'https://music.bugs.co.kr/track/5763626',
#   'https://music.bugs.co.kr/track/4374514',
#   'https://music.bugs.co.kr/track/4351681',
#   'https://music.bugs.co.kr/track/31379698',
#   'https://music.bugs.co.kr/track/31743260',
#   'https://music.bugs.co.kr/track/5635246',
#   'https://music.bugs.co.kr/track/30741365',
#   'https://music.bugs.co.kr/track/31016557',
#   'https://music.bugs.co.kr/track/5764262',
#   'https://music.bugs.co.kr/track/30262684',
#   'https://music.bugs.co.kr/track/4870462',
#   'https://music.bugs.co.kr/track/3626770',
#   'https://music.bugs.co.kr/track/31810223',
#   'https://music.bugs.co.kr/track/5745867',
#   'https://music.bugs.co.kr/track/3983043',
#   'https://music.bugs.co.kr/track/30530728',
#   'https://music.bugs.co.kr/track/4818311',
#   'https://music.bugs.co.kr/track/30741366',
#   'https://music.bugs.co.kr/track/30622542',
#   'https://music.bugs.co.kr/track/83437',
#   'https://music.bugs.co.kr/track/4793925',
#   'https://music.bugs.co.kr/track/4572363',
#   'https://music.bugs.co.kr/track/5550764',
#   'https://music.bugs.co.kr/track/4330817',
#   'https://music.bugs.co.kr/track/30337927',
#   'https://music.bugs.co.kr/track/30765285',
#   'https://music.bugs.co.kr/track/5436042',
#   'https://music.bugs.co.kr/track/31730856',
#   'https://music.bugs.co.kr/track/30327321',
#   'https://music.bugs.co.kr/track/31780295',
#   'https://music.bugs.co.kr/track/4374515',
#   'https://music.bugs.co.kr/track/4637446',
#   'https://music.bugs.co.kr/track/4793928',
#   'https://music.bugs.co.kr/track/30669977',
#   'https://music.bugs.co.kr/track/30391596',
#   'https://music.bugs.co.kr/track/30609287',
#   'https://music.bugs.co.kr/track/3626772',
#   'https://music.bugs.co.kr/track/30676786',
#   'https://music.bugs.co.kr/track/4669144',
#   'https://music.bugs.co.kr/track/31593098',
#   'https://music.bugs.co.kr/track/31153312',
#   'https://music.bugs.co.kr/track/5479883',
#   'https://music.bugs.co.kr/track/31642246',
#   'https://music.bugs.co.kr/track/4315824',
#   'https://music.bugs.co.kr/track/30973392',
#   'https://music.bugs.co.kr/track/30605027',
#   'https://music.bugs.co.kr/track/4592978',
#   'https://music.bugs.co.kr/track/31157637',
#   'https://music.bugs.co.kr/track/3116265',
#   'https://music.bugs.co.kr/track/519620',
#   'https://music.bugs.co.kr/track/31780287',
#   'https://music.bugs.co.kr/track/5127342',
#   'https://music.bugs.co.kr/track/2695370',
#   'https://music.bugs.co.kr/track/5639687',
#   'https://music.bugs.co.kr/track/30767527',
#   'https://music.bugs.co.kr/track/3768047',
#   'https://music.bugs.co.kr/track/31107979',
#   'https://music.bugs.co.kr/track/4695848',
#   'https://music.bugs.co.kr/track/5562263',
#   'https://music.bugs.co.kr/track/3500680',
#   'https://music.bugs.co.kr/track/30722091',
#   'https://music.bugs.co.kr/track/30565137',
#   'https://music.bugs.co.kr/track/3109825',
#   'https://music.bugs.co.kr/track/80090700',
#   'https://music.bugs.co.kr/track/1570303',
#   'https://music.bugs.co.kr/track/496573',
#   'https://music.bugs.co.kr/track/31686175',
#   'https://music.bugs.co.kr/track/30218889',
#   'https://music.bugs.co.kr/track/3368165',
#   'https://music.bugs.co.kr/track/5562273',
#   'https://music.bugs.co.kr/track/31566473',
#   'https://music.bugs.co.kr/track/1657702',
#   'https://music.bugs.co.kr/track/80307329',
#   'https://music.bugs.co.kr/track/5562271',
#   'https://music.bugs.co.kr/track/5836300',
#   'https://music.bugs.co.kr/track/30565138',
#   'https://music.bugs.co.kr/track/31783180',
#   'https://music.bugs.co.kr/track/5562264',
#   'https://music.bugs.co.kr/track/5139402',
#   'https://music.bugs.co.kr/track/2031242',
#   'https://music.bugs.co.kr/track/80307341',
#   'https://music.bugs.co.kr/track/4280859',
#   'https://music.bugs.co.kr/track/159405',
#   'https://music.bugs.co.kr/track/30303696',
#   'https://music.bugs.co.kr/track/30928835',
#   'https://music.bugs.co.kr/track/4840738',
#   'https://music.bugs.co.kr/track/500796',
#   'https://music.bugs.co.kr/track/2087644',
#   'https://music.bugs.co.kr/track/4807702',
#   'https://music.bugs.co.kr/track/5562265',
#   'https://music.bugs.co.kr/track/31855908',
#   'https://music.bugs.co.kr/track/3653986',
#   'https://music.bugs.co.kr/track/30775614',
#   'https://music.bugs.co.kr/track/3653983',
#   'https://music.bugs.co.kr/track/503009',
#   'https://music.bugs.co.kr/track/31227975',
#   'https://music.bugs.co.kr/track/5598004',
#   'https://music.bugs.co.kr/track/3587451',
#   'https://music.bugs.co.kr/track/3653982',
#   'https://music.bugs.co.kr/track/3653991',
#   'https://music.bugs.co.kr/track/4833358',
#   'https://music.bugs.co.kr/track/31227974',
#   'https://music.bugs.co.kr/track/4352347',
#   'https://music.bugs.co.kr/track/80164697',
#   'https://music.bugs.co.kr/track/80282596',
#   'https://music.bugs.co.kr/track/340163',
#   'https://music.bugs.co.kr/track/4352357',
#   'https://music.bugs.co.kr/track/31307761',
#   'https://music.bugs.co.kr/track/31086433',
#   'https://music.bugs.co.kr/track/80334441',
#   'https://music.bugs.co.kr/track/3653995',
#   'https://music.bugs.co.kr/track/4352343',
#   'https://music.bugs.co.kr/track/4799435',
#   'https://music.bugs.co.kr/track/4757601',
#   'https://music.bugs.co.kr/track/3414999',
#   'https://music.bugs.co.kr/track/31140303',
#   'https://music.bugs.co.kr/track/3129785',
#   'https://music.bugs.co.kr/track/3653984',
#   'https://music.bugs.co.kr/track/3653987',
#   'https://music.bugs.co.kr/track/30716114',
#   'https://music.bugs.co.kr/track/3653992',
#   'https://music.bugs.co.kr/track/3653988',
#   'https://music.bugs.co.kr/track/2042820',
#   'https://music.bugs.co.kr/track/3653985',
#   'https://music.bugs.co.kr/track/30238937',
#   'https://music.bugs.co.kr/track/4352344',
#   'https://music.bugs.co.kr/track/1855204',
#   'https://music.bugs.co.kr/track/31413842',
#   'https://music.bugs.co.kr/track/30711777',
#   'https://music.bugs.co.kr/track/3653993',
#   'https://music.bugs.co.kr/track/80042952',
#   'https://music.bugs.co.kr/track/4352354',
#   'https://music.bugs.co.kr/track/31084991',
#   'https://music.bugs.co.kr/track/2061697',
#   'https://music.bugs.co.kr/track/4995601',
#   'https://music.bugs.co.kr/track/31816236',
#   'https://music.bugs.co.kr/track/5575958',
#   'https://music.bugs.co.kr/track/31634571',
#   'https://music.bugs.co.kr/track/3653989',
#   'https://music.bugs.co.kr/track/3970810'],
#  ['https://music.bugs.co.kr/album/20278010',
#   'https://music.bugs.co.kr/album/5196',
#   'https://music.bugs.co.kr/album/5293',
#   'https://music.bugs.co.kr/album/5291',
#   'https://music.bugs.co.kr/album/865432',
#   'https://music.bugs.co.kr/album/3248',
#   'https://music.bugs.co.kr/album/417',
#   'https://music.bugs.co.kr/album/3248',
#   'https://music.bugs.co.kr/album/3248',
#   'https://music.bugs.co.kr/album/20052758',
#   'https://music.bugs.co.kr/album/189987',
#   'https://music.bugs.co.kr/album/366854',
#   'https://music.bugs.co.kr/album/939752',
#   'https://music.bugs.co.kr/album/16120',
#   'https://music.bugs.co.kr/album/8024686',
#   'https://music.bugs.co.kr/album/5196',
#   'https://music.bugs.co.kr/album/809295',
#   'https://music.bugs.co.kr/album/8008896',
#   'https://music.bugs.co.kr/album/8023074',
#   'https://music.bugs.co.kr/album/20166319',
#   'https://music.bugs.co.kr/album/675773',
#   'https://music.bugs.co.kr/album/20097399',
#   'https://music.bugs.co.kr/album/178999',
#   'https://music.bugs.co.kr/album/175183',
#   'https://music.bugs.co.kr/album/20127291',
#   'https://music.bugs.co.kr/album/2102',
#   'https://music.bugs.co.kr/album/10481122',
#   'https://music.bugs.co.kr/album/2102',
#   'https://music.bugs.co.kr/album/12113',
#   'https://music.bugs.co.kr/album/511239',
#   'https://music.bugs.co.kr/album/20237641',
#   'https://music.bugs.co.kr/album/417193',
#   'https://music.bugs.co.kr/album/8002647',
#   'https://music.bugs.co.kr/album/180231',
#   'https://music.bugs.co.kr/album/20237641',
#   'https://music.bugs.co.kr/album/5198',
#   'https://music.bugs.co.kr/album/5291',
#   'https://music.bugs.co.kr/album/8015522',
#   'https://music.bugs.co.kr/album/3156',
#   'https://music.bugs.co.kr/album/675773',
#   'https://music.bugs.co.kr/album/5291',
#   'https://music.bugs.co.kr/album/963379',
#   'https://music.bugs.co.kr/album/20072572',
#   'https://music.bugs.co.kr/album/925156',
#   'https://music.bugs.co.kr/album/5293',
#   'https://music.bugs.co.kr/album/20176765',
#   'https://music.bugs.co.kr/album/374117',
#   'https://music.bugs.co.kr/album/20077342',
#   'https://music.bugs.co.kr/album/20237641',
#   'https://music.bugs.co.kr/album/30841',
#   'https://music.bugs.co.kr/album/957400',
#   'https://music.bugs.co.kr/album/20314707',
#   'https://music.bugs.co.kr/album/20090733',
#   'https://music.bugs.co.kr/album/885512',
#   'https://music.bugs.co.kr/album/647192',
#   'https://music.bugs.co.kr/album/20058051',
#   'https://music.bugs.co.kr/album/939672',
#   'https://music.bugs.co.kr/album/839973',
#   'https://music.bugs.co.kr/album/20253591',
#   'https://music.bugs.co.kr/album/20130675',
#   'https://music.bugs.co.kr/album/939672',
#   'https://music.bugs.co.kr/album/507550',
#   'https://music.bugs.co.kr/album/504618',
#   'https://music.bugs.co.kr/album/20217118',
#   'https://music.bugs.co.kr/album/20286535',
#   'https://music.bugs.co.kr/album/880838',
#   'https://music.bugs.co.kr/album/20111926',
#   'https://music.bugs.co.kr/album/20157868',
#   'https://music.bugs.co.kr/album/940212',
#   'https://music.bugs.co.kr/album/20037055',
#   'https://music.bugs.co.kr/album/624831',
#   'https://music.bugs.co.kr/album/445050',
#   'https://music.bugs.co.kr/album/20300948',
#   'https://music.bugs.co.kr/album/932233',
#   'https://music.bugs.co.kr/album/492669',
#   'https://music.bugs.co.kr/album/20078997',
#   'https://music.bugs.co.kr/album/590671',
#   'https://music.bugs.co.kr/album/20111926',
#   'https://music.bugs.co.kr/album/20092683',
#   'https://music.bugs.co.kr/album/5422',
#   'https://music.bugs.co.kr/album/20058051',
#   'https://music.bugs.co.kr/album/532394',
#   'https://music.bugs.co.kr/album/842852',
#   'https://music.bugs.co.kr/album/502194',
#   'https://music.bugs.co.kr/album/20047978',
#   'https://music.bugs.co.kr/album/20116114',
#   'https://music.bugs.co.kr/album/800816',
#   'https://music.bugs.co.kr/album/20284163',
#   'https://music.bugs.co.kr/album/20046396',
#   'https://music.bugs.co.kr/album/20293803',
#   'https://music.bugs.co.kr/album/507550',
#   'https://music.bugs.co.kr/album/541713',
#   'https://music.bugs.co.kr/album/20058051',
#   'https://music.bugs.co.kr/album/20100088',
#   'https://music.bugs.co.kr/album/20056206',
#   'https://music.bugs.co.kr/album/20090733',
#   'https://music.bugs.co.kr/album/445050',
#   'https://music.bugs.co.kr/album/20101196',
#   'https://music.bugs.co.kr/album/20016683',
#   'https://music.bugs.co.kr/album/20254619',
#   'https://music.bugs.co.kr/album/20180771',
#   'https://music.bugs.co.kr/album/813812',
#   'https://music.bugs.co.kr/album/20264041',
#   'https://music.bugs.co.kr/album/499889',
#   'https://music.bugs.co.kr/album/20151435',
#   'https://music.bugs.co.kr/album/20090096',
#   'https://music.bugs.co.kr/album/535158',
#   'https://music.bugs.co.kr/album/20181348',
#   'https://music.bugs.co.kr/album/377918',
#   'https://music.bugs.co.kr/album/34289',
#   'https://music.bugs.co.kr/album/20293803',
#   'https://music.bugs.co.kr/album/713872',
#   'https://music.bugs.co.kr/album/333717',
#   'https://music.bugs.co.kr/album/882953',
#   'https://music.bugs.co.kr/album/20116605',
#   'https://music.bugs.co.kr/album/464044',
#   'https://music.bugs.co.kr/album/20173253',
#   'https://music.bugs.co.kr/album/554171',
#   'https://music.bugs.co.kr/album/849212',
#   'https://music.bugs.co.kr/album/428846',
#   'https://music.bugs.co.kr/album/20108860',
#   'https://music.bugs.co.kr/album/20083983',
#   'https://music.bugs.co.kr/album/376997',
#   'https://music.bugs.co.kr/album/8008067',
#   'https://music.bugs.co.kr/album/159161',
#   'https://music.bugs.co.kr/album/33244',
#   'https://music.bugs.co.kr/album/20273682',
#   'https://music.bugs.co.kr/album/20030298',
#   'https://music.bugs.co.kr/album/410587',
#   'https://music.bugs.co.kr/album/849212',
#   'https://music.bugs.co.kr/album/20249495',
#   'https://music.bugs.co.kr/album/171081',
#   'https://music.bugs.co.kr/album/8025131',
#   'https://music.bugs.co.kr/album/849212',
#   'https://music.bugs.co.kr/album/962052',
#   'https://music.bugs.co.kr/album/20083983',
#   'https://music.bugs.co.kr/album/20294367',
#   'https://music.bugs.co.kr/album/849212',
#   'https://music.bugs.co.kr/album/713872',
#   'https://music.bugs.co.kr/album/228575',
#   'https://music.bugs.co.kr/album/8025131',
#   'https://music.bugs.co.kr/album/495420',
#   'https://music.bugs.co.kr/album/16192',
#   'https://music.bugs.co.kr/album/20042860',
#   'https://music.bugs.co.kr/album/20143938',
#   'https://music.bugs.co.kr/album/611771',
#   'https://music.bugs.co.kr/album/15950',
#   'https://music.bugs.co.kr/album/239472',
#   'https://music.bugs.co.kr/album/597759',
#   'https://music.bugs.co.kr/album/849212',
#   'https://music.bugs.co.kr/album/20311746',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/20118155',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/33459',
#   'https://music.bugs.co.kr/album/20193122',
#   'https://music.bugs.co.kr/album/865432',
#   'https://music.bugs.co.kr/album/439684',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/608156',
#   'https://music.bugs.co.kr/album/20193122',
#   'https://music.bugs.co.kr/album/504719',
#   'https://music.bugs.co.kr/album/8014454',
#   'https://music.bugs.co.kr/album/8023074',
#   'https://music.bugs.co.kr/album/24539',
#   'https://music.bugs.co.kr/album/504719',
#   'https://music.bugs.co.kr/album/20206754',
#   'https://music.bugs.co.kr/album/20169484',
#   'https://music.bugs.co.kr/album/8027230',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/504719',
#   'https://music.bugs.co.kr/album/594774',
#   'https://music.bugs.co.kr/album/574876',
#   'https://music.bugs.co.kr/album/417193',
#   'https://music.bugs.co.kr/album/20178570',
#   'https://music.bugs.co.kr/album/379571',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/20107867',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/231011',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/20033333',
#   'https://music.bugs.co.kr/album/504719',
#   'https://music.bugs.co.kr/album/210413',
#   'https://music.bugs.co.kr/album/20222528',
#   'https://music.bugs.co.kr/album/20107144',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/8003332',
#   'https://music.bugs.co.kr/album/504719',
#   'https://music.bugs.co.kr/album/20169201',
#   'https://music.bugs.co.kr/album/234909',
#   'https://music.bugs.co.kr/album/666859',
#   'https://music.bugs.co.kr/album/20302385',
#   'https://music.bugs.co.kr/album/856461',
#   'https://music.bugs.co.kr/album/20262554',
#   'https://music.bugs.co.kr/album/448370',
#   'https://music.bugs.co.kr/album/491172'],
#  ['L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'L',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'u',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v',
#   'v'])

# %%
def get_suggestion_content(url_list):
    base_url2 = requests.get(url_list)
    soup2 = BeautifulSoup(base_url2.text, 'html.parser', from_encoding="utf8")
    lyrics_list = [] 
    tags1 = soup2.select('#container > header > div')[0].find_all('h1')
    title = tags1[0].get_text(strip=True).replace('(inst.)','')
    tags2 = soup2.select('#container > section.sectionPadding.contents.lyrics > div > div')[0].find_all('xmp')
    try : 
        lyrics = tags2[0].get_text(strip=True).replace('\r\n',' ').replace('\r',' ').replace('\n',' ')
    except : 
        lyrics = '' 
    #container > section.sectionPadding.summaryInfo.summaryTrack > div > div.basicInfo > table > tbody > tr:nth-child(1) > th
    tags3 = soup2.select('#container > section.sectionPadding.summaryInfo.summaryTrack > div > div.basicInfo > table > tbody')[0].find_all('td')
    artist = tags3[0].get_text(strip=True)
    
    #container > section.sectionPadding.summaryInfo.summaryTrack > div > div.etcInfo > span > a > span > em
    tags4 = soup2.select('#container > section.sectionPadding.summaryInfo.summaryTrack > div > div.etcInfo > span > a > span')[0].find_all('em')
    like = tags4[0].get_text(strip=True).replace(',','')

    
    lyrics_list.append(artist)
    lyrics_list.append(title)
    lyrics_list.append(like)
    lyrics_list.append(lyrics)
        
    return lyrics_list

# %%
def get_suggestion_album(url_list):
    base_url2 = requests.get(url_list)
    soup2 = BeautifulSoup(base_url2.text, 'html.parser', from_encoding="utf8")
    info = []
    tags1 = soup2.select('#container > section.sectionPadding.summaryInfo.summaryAlbum > div > div.basicInfo > table')[0].find_all('time')
    datetime = tags1[0].get_text(strip=True)
    #container > section.sectionPadding.summaryInfo.summaryAlbum > div > div.basicInfo > table > tbody > tr:nth-child(4) > td
    tags2 = soup2.select('#container > section.sectionPadding.summaryInfo.summaryAlbum > div > div.basicInfo > table > tbody')[0].find_all('td')
    genre = tags2[4].get_text(strip=True)
       
    info.append(datetime)
    info.append(genre)
        
    return info

# %%
get_suggestion_album("https://music.bugs.co.kr/track/31705498")

# %%
def get_data(singer, pages): 
    data1= []
    data2= [] 
    
    suggestion_list = get_suggestion_list(singer,pages)[0]
    info_list = get_suggestion_list(singer,pages)[1]  
    singer_list = get_suggestion_list(singer,pages)[2]
    
    for i, suggestion in tqdm(enumerate(suggestion_list)):
        s = get_suggestion_content(suggestion)
        data1.append(s)
    
    for i, info in tqdm(enumerate(info_list)):
        s = get_suggestion_album(info)
        data2.append(s)
        
    data1 = pd.DataFrame(data1, columns=["Artist","Title","Like","Lyrics"])
    data2 = pd.DataFrame(data2, columns=["Datetime","Genre"])
    data3 = pd.DataFrame(singer_list, columns=["Keyword"])
    data = pd.concat([data3, data1, data2], axis = 1)
    
    return data

# %% [markdown]
# ###  ------------------------------------------- 여기까지 클롤링 불러오는 코드  --------------------------------------------

# %%
singer = ["Lauv"]
data = get_data(singer, 1) #페이지1에 곡 50개
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\bs4\__init__.py:185: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
#
# 0it [00:00, ?it/s]
# 1it [00:00,  1.62it/s]
# 2it [00:00,  1.93it/s]
# 3it [00:01,  1.86it/s]
# 4it [00:01,  2.01it/s]
# 5it [00:02,  2.05it/s]
# 6it [00:02,  2.06it/s]
# 7it [00:03,  1.94it/s]
# 8it [00:04,  1.46it/s]
# 9it [00:05,  1.53it/s]
# 10it [00:05,  1.73it/s]
# 11it [00:05,  1.83it/s]
# 12it [00:06,  1.96it/s]
# 13it [00:07,  1.74it/s]
# 14it [00:07,  1.81it/s]
# 15it [00:08,  1.92it/s]
# 16it [00:08,  2.28it/s]
# 17it [00:08,  2.25it/s]
# 18it [00:09,  2.14it/s]
# 19it [00:09,  2.18it/s]
# 20it [00:10,  2.32it/s]
# 21it [00:10,  2.14it/s]
# 22it [00:11,  2.10it/s]
# 23it [00:11,  2.41it/s]
# 24it [00:11,  2.57it/s]
# 25it [00:12,  2.44it/s]
# 26it [00:12,  2.66it/s]
# 27it [00:12,  3.09it/s]
# 28it [00:12,  3.45it/s]
# 29it [00:13,  3.45it/s]
# 30it [00:13,  3.98it/s]
# 31it [00:13,  4.02it/s]
# 32it [00:13,  4.49it/s]
# 33it [00:14,  4.26it/s]
# 34it [00:14,  3.93it/s]
# 35it [00:14,  3.55it/s]
# 36it [00:15,  2.96it/s]
# 37it [00:15,  2.86it/s]
# 38it [00:15,  3.27it/s]
# 39it [00:15,  3.82it/s]
# 40it [00:16,  4.31it/s]
# 41it [00:16,  4.44it/s]
# 42it [00:16,  4.87it/s]
# 43it [00:16,  5.09it/s]
# 44it [00:16,  5.20it/s]
# 45it [00:16,  5.52it/s]
# 46it [00:17,  5.62it/s]
# 47it [00:17,  5.58it/s]
# 48it [00:17,  5.12it/s]
# 49it [00:17,  5.47it/s]
# 50it [00:17,  2.80it/s]
#
# 0it [00:00, ?it/s]
# 1it [00:00,  3.43it/s]
# 2it [00:00,  3.53it/s]
# 3it [00:00,  4.12it/s]
# 4it [00:00,  4.62it/s]
# 5it [00:01,  5.03it/s]
# 6it [00:01,  5.04it/s]
# 7it [00:01,  4.97it/s]
# 8it [00:01,  5.13it/s]
# 9it [00:01,  4.89it/s]
# 10it [00:02,  4.67it/s]
# 11it [00:02,  5.12it/s]
# 12it [00:02,  5.52it/s]
# 13it [00:02,  5.69it/s]
# 14it [00:02,  5.95it/s]
# 15it [00:02,  5.88it/s]
# 16it [00:03,  5.36it/s]
# 17it [00:03,  5.18it/s]
# 18it [00:03,  5.34it/s]
# 19it [00:03,  4.88it/s]
# 20it [00:03,  5.09it/s]
# 21it [00:04,  4.44it/s]
# 22it [00:04,  4.28it/s]
# 23it [00:04,  4.47it/s]
# 24it [00:04,  4.38it/s]
# 25it [00:05,  4.24it/s]
# 26it [00:05,  4.39it/s]
# 27it [00:05,  4.48it/s]
# 28it [00:05,  4.63it/s]
# 29it [00:05,  4.74it/s]
# 30it [00:06,  4.74it/s]
# 31it [00:06,  4.75it/s]
# 32it [00:06,  3.99it/s]
# 33it [00:06,  4.17it/s]
# 34it [00:07,  4.04it/s]
# 35it [00:07,  4.29it/s]
# 36it [00:07,  4.75it/s]
# 37it [00:07,  4.90it/s]
# 38it [00:07,  5.10it/s]
# 39it [00:08,  5.36it/s]
# 40it [00:08,  5.31it/s]
# 41it [00:08,  4.91it/s]
# 42it [00:08,  4.34it/s]
# 43it [00:09,  4.48it/s]
# 44it [00:09,  4.61it/s]
# 45it [00:09,  4.09it/s]
# 46it [00:09,  4.28it/s]
# 47it [00:09,  4.60it/s]
# 48it [00:10,  5.15it/s]
# 49it [00:10,  5.11it/s]
# 50it [00:10,  4.79it/s]

# %%
### 가수 'Lauv' 불러오기
data.head(50)
# Out:
#    Keyword                                             Artist  \
# 0     Lauv                              Lauv(라우브)CONNECT 아티스트
# 1     Lauv                              Lauv(라우브)CONNECT 아티스트
# 2     Lauv                              Lauv(라우브)CONNECT 아티스트
# 3     Lauv  Lauv(라우브)CONNECT 아티스트,Troye Sivan(트로이 시반)CONNE...
# 4     Lauv                                              방탄소년단
# 5     Lauv                              Lauv(라우브)CONNECT 아티스트
# 6     Lauv                              Lauv(라우브)CONNECT 아티스트
# 7     Lauv                              Lauv(라우브)CONNECT 아티스트
# 8     Lauv                    Lauv(라우브)CONNECT 아티스트,LANY(레이니)
# 9     Lauv                              Lauv(라우브)CONNECT 아티스트
# 10    Lauv                              Lauv(라우브)CONNECT 아티스트
# 11    Lauv                              Lauv(라우브)CONNECT 아티스트
# 12    Lauv                              Lauv(라우브)CONNECT 아티스트
# 13    Lauv                              Lauv(라우브)CONNECT 아티스트
# 14    Lauv                              Lauv(라우브)CONNECT 아티스트
# 15    Lauv                              Lauv(라우브)CONNECT 아티스트
# 16    Lauv                              Lauv(라우브)CONNECT 아티스트
# 17    Lauv                              Lauv(라우브)CONNECT 아티스트
# 18    Lauv                              Lauv(라우브)CONNECT 아티스트
# 19    Lauv                              Lauv(라우브)CONNECT 아티스트
# 20    Lauv                              Lauv(라우브)CONNECT 아티스트
# 21    Lauv                              Lauv(라우브)CONNECT 아티스트
# 22    Lauv                              Lauv(라우브)CONNECT 아티스트
# 23    Lauv                              Lauv(라우브)CONNECT 아티스트
# 24    Lauv                              Lauv(라우브)CONNECT 아티스트
# 25    Lauv                              Lauv(라우브)CONNECT 아티스트
# 26    Lauv                              Lauv(라우브)CONNECT 아티스트
# 27    Lauv                              Lauv(라우브)CONNECT 아티스트
# 28    Lauv                              Lauv(라우브)CONNECT 아티스트
# 29    Lauv                              Lauv(라우브)CONNECT 아티스트
# 30    Lauv  Lauv(라우브)CONNECT 아티스트,Troye Sivan(트로이 시반)CONNE...
# 31    Lauv                              Lauv(라우브)CONNECT 아티스트
# 32    Lauv                              Lauv(라우브)CONNECT 아티스트
# 33    Lauv                              Lauv(라우브)CONNECT 아티스트
# 34    Lauv                              Lauv(라우브)CONNECT 아티스트
# 35    Lauv                              Lauv(라우브)CONNECT 아티스트
# 36    Lauv                              Lauv(라우브)CONNECT 아티스트
# 37    Lauv                                              방탄소년단
# 38    Lauv                              Lauv(라우브)CONNECT 아티스트
# 39    Lauv                                              방탄소년단
# 40    Lauv                              Lauv(라우브)CONNECT 아티스트
# 41    Lauv                              Lauv(라우브)CONNECT 아티스트
# 42    Lauv                              Lauv(라우브)CONNECT 아티스트
# 43    Lauv                              Lauv(라우브)CONNECT 아티스트
# 44    Lauv                              Lauv(라우브)CONNECT 아티스트
# 45    Lauv                              Lauv(라우브)CONNECT 아티스트
# 46    Lauv                              Lauv(라우브)CONNECT 아티스트
# 47    Lauv                              Lauv(라우브)CONNECT 아티스트
# 48    Lauv                              Lauv(라우브)CONNECT 아티스트
# 49    Lauv  Lauv(라우브)CONNECT 아티스트,Troye Sivan(트로이 시반)CONNE...
#
#                                                 Title   Like  \
# 0                                   Paris In The Rain  15036
# 1                                             Changes   3413
# 2                 fuck, i'm lonely (feat. Anne-Marie)   5797
# 3                                     i'm so tired...  10448
# 4                          Make It Right (feat. Lauv)   3702
# 5                                    I Like Me Better   7831
# 6                                           Never Not   4349
# 7                                            Feelings   2452
# 8                                             Mean It   1568
# 9                                     Who (feat. BTS)   1821
# 10                               Drugs & The Internet   2187
# 11                                               Sims   1487
# 12                                   Tattoos Together    894
# 13                                        Sad Forever   1457
# 14                               The Story Never Ends   1779
# 15                                  Modern Loneliness   1023
# 16                                               Sims    885
# 17                                   I Like Me Better   1752
# 18                                       Chasing Fire   1078
# 19                                        Comfortable   1185
# 20                                          Superhero    946
# 21              There's No Way (feat. Julia Michaels)   1196
# 22                                           Reforget    578
# 23                                          Easy Love   1745
# 24                                         Adrenaline    889
# 25                                           Feelings    308
# 26                                          The Other    629
# 27                                           Paranoid    575
# 28                                            Enemies    631
# 29                                            Breathe    493
# 30            i'm so tired... (Stripped - Live in LA)    684
# 31                                   Getting Over You    567
# 32                                   Invisible Things    245
# 33                               Drugs & The Internet    242
# 34  Drugs & The Internet (stripped - a one-take vibe)    575
# 35                                          The Other   1412
# 36                                            Breathe   1042
# 37             Make It Right (feat. Lauv) (EDM Remix)    542
# 38                               Sims (Miquela Remix)    219
# 39        Make It Right (feat. Lauv) (Acoustic Remix)    548
# 40               fuck, i'm lonely  (feat. Anne-Marie)    183
# 41                                        Lonely Eyes    239
# 42                                              Julia    247
# 43                        Canada (feat. Alessia Cara)    225
# 44                                        Sad Forever    171
# 45                          lonely (feat. Anne-Marie)    197
# 46                                          Easy Love    289
# 47                                           Bracelet    324
# 48                                              Billy    196
# 49                                    i'm so tired...    118
#
#                                                Lyrics    Datetime       Genre
# 0   All I know is ooh ooh ooh We could go anywhere...  2018.10.08           팝
# 1   I'm getting rid of my clothes I don't wear I t...  2020.01.03           팝
# 2   I call you one time two time three time I  Can...  2019.08.02           팝
# 3   I'm so tired of love songs Tired of love songs...  2019.01.25           팝
# 4   I was lost I was tryna find the answer In the ...  2019.10.18          힙합
# 5   To be young and in love in new york city To no...  2018.02.13           팝
# 6   We were so beautiful We were so tragic No othe...  2018.10.08           팝
# 7   Is my love too much? Is it just enough for you...  2019.09.20           팝
# 8   Small talk no conversation That look makes me ...  2019.11.15           팝
# 9   Outlines of your eyes and visions of you Girl ...  2020.03.06           팝
# 10  Another life another story She walked out said...  2019.05.03           팝
# 11  I wish that you and I lived in the Sims We cou...  2019.10.04           팝
# 12  Said I'd never fall, I'd never fall, I'd never...  2020.01.17           팝
# 13  Daydream Life feels like a daydream And I just...  2019.06.13           팝
# 14  Stick stick to your stones cause that's all yo...  2018.10.08           팝
# 15  I've been thinkin' 'bout my father lately The ...  2020.03.06           팝
# 16  I wish that you and I lived in the Sims We cou...  2020.03.06           팝
# 17  To be young and in love in New York City To no...  2018.10.08           팝
# 18  I wanna hate you 'cause I still love you And i...  2018.10.08           팝
# 19  Laying here wrapped in white  Just trying to n...  2018.10.08           팝
# 20  I met a superhero I lost her I want her back S...  2018.10.18           팝
# 21  You touch me and it's almost like we knew  Tha...  2018.10.01           팝
# 22  Didn't wanna be a ghost But you pushed me over...  2018.10.08           팝
# 23  You got a way of making me feel insane Like I ...  2018.02.13           팝
# 24  Remembering what you said Now I'm laying alone...  2018.10.08           팝
# 25  Is my love too much? Is it just enough for you...  2020.03.06           팝
# 26  Like a spotlight the water hits me Ran it extr...  2018.10.08           팝
# 27  Smile when you're sleeping Wonder who you're d...  2018.10.08           팝
# 28  I thought we said we're good Was I misundersto...  2018.10.08           팝
# 29  I've watched those eyes light up with a smile ...  2018.10.08           팝
# 30  I'm so tired of love songs Tired of love songs...  2019.03.15           팝
# 31  Running from the morning Think I hit a wall La...  2018.10.08           팝
# 32  Do you still remember the way that we felt whe...  2020.03.06           팝
# 33  Another life another story She walked out said...  2020.03.06           팝
# 34  Another life another story She walked out said...  2019.05.27           팝
# 35  Like a spotlight the water hits me Ran it extr...  2017.10.12           팝
# 36  I've watched those eyes Light up with a smile ...  2017.10.12           팝
# 37  I was lost I was tryna find the answer In the ...  2019.11.01  힙합,일렉트로닉 팝
# 38  I wish that you and I lived in The Sims We cou...  2019.10.30           팝
# 39  I was lost I was tryna find the answer In the ...  2019.11.08          힙합
# 40  I call you one time two time three time I  Can...  2020.03.06           팝
# 41  She was sixteen the first time she had her hea...  2020.03.06           팝
# 42  When we met When we met I wasn’t me, I was so ...  2020.03.06           팝
# 43  Waking up in your bed It’s almost like I’ve be...  2020.03.06           팝
# 44  Daydream Life feels like a daydream And I just...  2020.03.06           팝
# 45  Call you one time, two time, three time, I can...  2019.08.02           팝
# 46  You got a way of makin' me feel insane Like I ...  2018.10.08           팝
# 47  Didn’t know what I wanted I’ll admit that Stil...  2018.10.08           팝
# 48  Billy had dreams of a sailor or an astronaut N...  2020.03.06           팝
# 49  I'm so tired of love songs Tired of love songs...  2020.03.06           팝

# %%
data["Lyrics"]
# Out:
# 0     All I know is ooh ooh ooh We could go anywhere...
# 1     I'm getting rid of my clothes I don't wear I t...
# 2     I call you one time two time three time I  Can...
# 3     I'm so tired of love songs Tired of love songs...
# 4     I was lost I was tryna find the answer In the ...
# 5     To be young and in love in new york city To no...
# 6     We were so beautiful We were so tragic No othe...
# 7     Is my love too much? Is it just enough for you...
# 8     Small talk no conversation That look makes me ...
# 9     Outlines of your eyes and visions of you Girl ...
# 10    Another life another story She walked out said...
# 11    I wish that you and I lived in the Sims We cou...
# 12    Said I'd never fall, I'd never fall, I'd never...
# 13    Daydream Life feels like a daydream And I just...
# 14    Stick stick to your stones cause that's all yo...
# 15    I've been thinkin' 'bout my father lately The ...
# 16    I wish that you and I lived in the Sims We cou...
# 17    To be young and in love in New York City To no...
# 18    I wanna hate you 'cause I still love you And i...
# 19    Laying here wrapped in white  Just trying to n...
# 20    I met a superhero I lost her I want her back S...
# 21    You touch me and it's almost like we knew  Tha...
# 22    Didn't wanna be a ghost But you pushed me over...
# 23    You got a way of making me feel insane Like I ...
# 24    Remembering what you said Now I'm laying alone...
# 25    Is my love too much? Is it just enough for you...
# 26    Like a spotlight the water hits me Ran it extr...
# 27    Smile when you're sleeping Wonder who you're d...
# 28    I thought we said we're good Was I misundersto...
# 29    I've watched those eyes light up with a smile ...
# 30    I'm so tired of love songs Tired of love songs...
# 31    Running from the morning Think I hit a wall La...
# 32    Do you still remember the way that we felt whe...
# 33    Another life another story She walked out said...
# 34    Another life another story She walked out said...
# 35    Like a spotlight the water hits me Ran it extr...
# 36    I've watched those eyes Light up with a smile ...
# 37    I was lost I was tryna find the answer In the ...
# 38    I wish that you and I lived in The Sims We cou...
# 39    I was lost I was tryna find the answer In the ...
# 40    I call you one time two time three time I  Can...
# 41    She was sixteen the first time she had her hea...
# 42    When we met When we met I wasn’t me, I was so ...
# 43    Waking up in your bed It’s almost like I’ve be...
# 44    Daydream Life feels like a daydream And I just...
# 45    Call you one time, two time, three time, I can...
# 46    You got a way of makin' me feel insane Like I ...
# 47    Didn’t know what I wanted I’ll admit that Stil...
# 48    Billy had dreams of a sailor or an astronaut N...
# 49    I'm so tired of love songs Tired of love songs...
# Name: Lyrics, dtype: object

# %% [markdown]
# ### 다른시도.. 토픽 모델링

# %%
count_vect = CountVectorizer(max_df=0.95, max_features=1000, min_df=2, stop_words='english', ngram_range=(1,2))
feat_vect = count_vect.fit_transform(data["Lyrics"])
print('CountVectorizer Shape:', feat_vect.shape)
# Out:
# CountVectorizer Shape: (50, 1000)

# %%
### LDA 클래스 
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=5, random_state=0)
lda.fit(feat_vect)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=5, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
def display_topic_words(model, feature_names, no_top_words):
    for topic_index, topic in enumerate(model.components_):
        print('\nTopic #',topic_index)

        # components_ array에서 가장 값이 큰 순으로 정렬했을 때, 그 값의 array index를 반환. 
        ### argsort - feature name을 가져오기 위해 위치를 반환해주는 함수 사용
        topic_word_indexes = topic.argsort()[::-1]
        top_indexes=topic_word_indexes[:no_top_words]
        
        # top_indexes대상인 index별로 feature_names에 해당하는 word feature 추출 후 join으로 concat
        feature_concat = ' + '.join([str(feature_names[i])+'*'+str(round(topic[i],1)) for i in top_indexes])                
        print(feature_concat)

# CountVectorizer객체내의 전체 word들의 명칭을 get_features_names( )를 통해 추출
feature_names = count_vect.get_feature_names()

# Topic별 가장 연관도가 높은 word를 15개만 추출
display_topic_words(lda, feature_names, 15)
# Out:
# Topic # 0
# right*75.0 + make*43.0 + oh*42.3 + right right*30.2 + oh make*27.2 + make right*27.2 + knows*20.2 + cause*17.0 + know*17.0 + knows knows*16.2 + lonely*16.1 + right oh*15.2 + set*14.2 + feel*13.8 + head*11.0
#
# Topic # 1
# let*67.3 + wouldn*53.2 + wouldn let*46.2 + let wouldn*34.2 + wish*30.5 + easy*26.2 + met*26.2 + love*25.8 + easy love*24.2 + baby*23.8 + night*23.5 + ll*21.3 + getting*20.2 + know*19.0 + way*19.0
#
# Topic # 2
# don*67.8 + lonely*63.2 + come*53.7 + lonely lonely*45.2 + know*38.0 + ooh*37.4 + don know*36.0 + hold*27.2 + come hold*27.2 + want*24.9 + don want*24.2 + hit*24.2 + did*21.2 + friends*21.2 + fuck*19.1
#
# Topic # 3
# love*153.0 + mmm*96.2 + tired*95.2 + tired love*93.2 + wanna*89.2 + home*78.1 + just*73.6 + songs*67.2 + love songs*67.2 + wanna home*67.2 + songs tired*66.2 + mmm mmm*66.2 + yeah*53.3 + home wanna*44.2 + cause*43.5
#
# Topic # 4
# don*156.5 + wanna*93.2 + don wanna*87.2 + sad*59.2 + wanna sad*54.2 + need*47.2 + like*45.2 + know*39.8 + stay*33.5 + better*33.1 + sad don*30.2 + like better*26.2 + cause*25.2 + just*20.7 + wake*20.2

# %%
doc_topics = lda.transform(feat_vect)
print(doc_topics.shape)
print(doc_topics[:3])
# Out:
# (50, 5)
# [[1.38759849e-01 1.87181618e-03 3.07356213e-01 2.46813235e-01
#   3.05198887e-01]
#  [2.14958723e-03 1.24366104e-01 6.51553007e-01 2.12038499e-03
#   2.19810917e-01]
#  [5.82345456e-04 5.81630079e-04 9.97672122e-01 5.81847745e-04
#   5.82055189e-04]]

# %%
import pandas as pd 

topic_names = ['Topic #'+ str(i) for i in range(0, 5)]
doc_topic_df = pd.DataFrame(data=doc_topics, columns=topic_names, index=data["Title"])
doc_topic_df.head(20)
# Out:
#                                      Topic #0  Topic #1  Topic #2  Topic #3  \
# Title
# Paris In The Rain                    0.138760  0.001872  0.307356  0.246813
# Changes                              0.002150  0.124366  0.651553  0.002120
# fuck, i'm lonely (feat. Anne-Marie)  0.000582  0.000582  0.997672  0.000582
# i'm so tired...                      0.000513  0.000513  0.000514  0.997947
# Make It Right (feat. Lauv)           0.998005  0.000499  0.000498  0.000499
# I Like Me Better                     0.001160  0.001169  0.001162  0.001172
# Never Not                            0.003937  0.003950  0.003963  0.918474
# Feelings                             0.000758  0.000760  0.000758  0.996963
# Mean It                              0.000881  0.000888  0.000878  0.775467
# Who (feat. BTS)                      0.268419  0.002814  0.002819  0.523861
# Drugs & The Internet                 0.000824  0.000827  0.996684  0.000832
# Sims                                 0.000864  0.996544  0.000864  0.000865
# Tattoos Together                     0.001603  0.001610  0.001603  0.993551
# Sad Forever                          0.000485  0.000485  0.000485  0.000485
# The Story Never Ends                 0.003032  0.987841  0.003027  0.003065
# Modern Loneliness                    0.001918  0.014547  0.425257  0.556309
# Sims                                 0.000864  0.996544  0.000864  0.000865
# I Like Me Better                     0.001174  0.001182  0.001176  0.001186
# Chasing Fire                         0.001869  0.001913  0.001875  0.992449
# Comfortable                          0.001581  0.001592  0.001589  0.993598
#
#                                      Topic #4
# Title
# Paris In The Rain                    0.305199
# Changes                              0.219811
# fuck, i'm lonely (feat. Anne-Marie)  0.000582
# i'm so tired...                      0.000514
# Make It Right (feat. Lauv)           0.000499
# I Like Me Better                     0.995337
# Never Not                            0.069675
# Feelings                             0.000761
# Mean It                              0.221886
# Who (feat. BTS)                      0.202088
# Drugs & The Internet                 0.000833
# Sims                                 0.000864
# Tattoos Together                     0.001634
# Sad Forever                          0.998060
# The Story Never Ends                 0.003036
# Modern Loneliness                    0.001969
# Sims                                 0.000864
# I Like Me Better                     0.995282
# Chasing Fire                         0.001895
# Comfortable                          0.001639

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorization 적용하여 학습 데이터셋과 테스트 데이터 셋 변환. 
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(text_lyrics)
X_tfidf_vect = tfidf_vect.transform(text_lyrics)

# %%
def display_topic_words(model, feature_names, no_top_words):
    for topic_index, topic in enumerate(model.components_):
        print('\nTopic #',topic_index)

        # components_ array에서 가장 값이 큰 순으로 정렬했을 때, 그 값의 array index를 반환. 
        ### argsort - feature name을 가져오기 위해 위치를 반환해주는 함수 사용
        topic_word_indexes = topic.argsort()[::-1]
        top_indexes=topic_word_indexes[:no_top_words]
        
        # top_indexes대상인 index별로 feature_names에 해당하는 word feature 추출 후 join으로 concat
        feature_concat = ' + '.join([str(feature_names[i])+'*'+str(round(topic[i],1)) for i in top_indexes])                
        print(feature_concat)

# CountVectorizer객체내의 전체 word들의 명칭을 get_features_names( )를 통해 추출
feature_names = tfidf_vect.get_feature_names()

# Topic별 가장 연관도가 높은 word를 15개만 추출
display_topic_words(lda, feature_names, 15)
# Out:
# Topic # 0
# one*75.0 + leave*43.0 + minute*42.3 + other*30.2 + mmm*27.2 + letters*27.2 + hands*20.2 + better*17.0 + got*17.0 + hard*16.2 + internet*16.1 + or*15.2 + promises*14.2 + cried*13.8 + face*11.0
#
# Topic # 1
# hesitation*67.3 + together*53.2 + tomorrow*46.2 + hits*34.2 + thorns*30.5 + collar*26.2 + loneliness*26.2 + knew*25.8 + come*24.2 + along*23.8 + memories*23.5 + insane*21.3 + down*20.2 + got*19.0 + their*19.0
#
# Topic # 2
# changes*67.8 + internet*63.2 + brings*53.7 + invisible*45.2 + got*38.0 + moonlight*37.4 + chasing*36.0 + fifth*27.2 + broke*27.2 + tastes*24.9 + chilling*24.2 + fault*24.2 + castles*21.2 + do*21.2 + door*19.1
#
# Topic # 3
# knew*153.0 + love*96.2 + slip*95.2 + small*93.2 + sure*89.2 + fingers*78.1 + fun*73.6 + remember*67.2 + laughing*67.2 + sweat*67.2 + remembering*66.2 + lucky*66.2 + toy*53.3 + first*44.2 + better*43.5
#
# Topic # 4
# changes*156.5 + sure*93.2 + chillin*87.2 + paranoid*59.2 + sweeter*54.2 + matter*47.2 + hours*45.2 + got*39.8 + rocks*33.5 + arms*33.1 + parts*30.2 + house*26.2 + better*25.2 + fun*20.7 + still*20.2

# %%
text_lyrics = data["Lyrics"]
#text_lyrics = pd.DataFrame(text_lyrics)
#text_lyrics.head(1)

# %% [markdown]
# ### 문장 토큰화, 단어 토큰화

# %%
from nltk import word_tokenize, sent_tokenize

#여러개의 문장으로 된 입력 데이터를 문장별로 단어 토큰화 만드는 함수 생성
def tokenize_text(text):
    
    # 문장별로 분리 토큰
    sentences = sent_tokenize(text)
    # 분리된 문장별 단어 토큰화
    word_tokens = [word_tokenize(sentence) for sentence in sentences]
    return word_tokens


#여러 문장들에 대해 문장별 단어 토큰화 수행. 
#word_tokens = tokenize_text(text_lyrics)
#print(type(word_tokens),len(word_tokens))
#print(word_tokens)

# %%
word_tokens = tokenize_text(text_lyrics)

# %%
text_sample = 'All I know is ooh ooh ooh We could go anywhere'
word_tokens = tokenize_text(text_sample)
print(word_tokens)
# Out:
# [['All', 'I', 'know', 'is', 'ooh', 'ooh', 'ooh', 'We', 'could', 'go', 'anywhere']]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Count Vectorization으로 feature extraction 변환 수행. 
cnt_vect = CountVectorizer()
cnt_vect.fit(text_lyrics)
X_train_cnt_vect = cnt_vect.transform(text_lyrics)

print('학습 데이터 Text의 CountVectorizer Shape:',X_train_cnt_vect.shape)
# Out:
# 학습 데이터 Text의 CountVectorizer Shape: (50, 989)

# %% [markdown]
# ### 여기서 가장 많이 나온 단어를 추출하는 방법?....

# %%
print(X_train_cnt_vect)
# Out:
#   (0, 1)	2
#   (0, 13)	4
#   (0, 15)	1
#   (0, 22)	1
#   (0, 23)	10
#   (0, 28)	1
#   (0, 30)	9
#   (0, 34)	1
#   (0, 41)	3
#   (0, 46)	2
#   (0, 56)	1
#   (0, 71)	1
#   (0, 85)	2
#   (0, 104)	1
#   (0, 114)	2
#   (0, 122)	4
#   (0, 131)	1
#   (0, 139)	1
#   (0, 147)	4
#   (0, 156)	3
#   (0, 176)	1
#   (0, 183)	1
#   (0, 185)	1
#   (0, 191)	3
#   (0, 195)	4
#   :	:
#   (49, 658)	1
#   (49, 679)	9
#   (49, 683)	1
#   (49, 689)	2
#   (49, 690)	24
#   (49, 694)	1
#   (49, 709)	1
#   (49, 715)	2
#   (49, 717)	1
#   (49, 729)	1
#   (49, 730)	1
#   (49, 744)	2
#   (49, 745)	1
#   (49, 751)	2
#   (49, 754)	1
#   (49, 771)	32
#   (49, 772)	3
#   (49, 795)	1
#   (49, 807)	1
#   (49, 828)	24
#   (49, 851)	1
#   (49, 863)	1
#   (49, 866)	8
#   (49, 885)	4
#   (49, 889)	3

# %%
cnt_vect = CountVectorizer(max_features=1, stop_words='english')


cnt_vect.fit(text_lyrics)
ftr_vect = cnt_vect.transform(text_lyrics)
print(type(ftr_vect), ftr_vect.shape)
print(cnt_vect.vocabulary_)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'> (50, 1)
# {'don': 0}

# %%
print(ftr_vect)
# Out:
#   (0, 0)	4
#   (1, 0)	2
#   (2, 0)	16
#   (3, 0)	1
#   (5, 0)	1
#   (8, 0)	37
#   (9, 0)	1
#   (10, 0)	2
#   (13, 0)	47
#   (15, 0)	11
#   (17, 0)	1
#   (20, 0)	3
#   (21, 0)	1
#   (22, 0)	3
#   (23, 0)	6
#   (24, 0)	4
#   (26, 0)	3
#   (28, 0)	4
#   (30, 0)	1
#   (31, 0)	1
#   (33, 0)	2
#   (34, 0)	2
#   (35, 0)	3
#   (40, 0)	16
#   (41, 0)	8
#   (43, 0)	6
#   (44, 0)	47
#   (45, 0)	16
#   (46, 0)	6
#   (47, 0)	12
#   (49, 0)	1

# %%
pprint(text_lyrics.vocab().most_common(10))
# Out:
# Pretty printing has been turned ON

# %%
df = data[data['Artist']=='Lauv(라우브)CONNECT 아티스트']
data[data['Artist']=='Lauv(라우브)CONNECT 아티스트'].head(3)
# Out:
#   Keyword                 Artist                                Title   Like  \
# 0    Lauv  Lauv(라우브)CONNECT 아티스트                    Paris In The Rain  15036
# 1    Lauv  Lauv(라우브)CONNECT 아티스트                              Changes   3413
# 2    Lauv  Lauv(라우브)CONNECT 아티스트  fuck, i'm lonely (feat. Anne-Marie)   5797
#
#                                               Lyrics    Datetime Genre
# 0  All I know is ooh ooh ooh We could go anywhere...  2018.10.08     팝
# 1  I'm getting rid of my clothes I don't wear I t...  2020.01.03     팝
# 2  I call you one time two time three time I  Can...  2019.08.02     팝

# %%
df['Lyrics'].isnull().sum()
# Out:
# 0

# %%
data = data['Lyrics'].dropna().reset_index()

# %%
data.head(5)
# Out:
#    index                                             Lyrics
# 0      0  All I know is ooh ooh ooh We could go anywhere...
# 1      1  I'm getting rid of my clothes I don't wear I t...
# 2      2  I call you one time two time three time I  Can...
# 3      3  I'm so tired of love songs Tired of love songs...
# 4      4  I was lost I was tryna find the answer In the ...

# %%
sample_content = data['Lyrics'][40]

#sample_content = pd.DataFrame(sample_content)
type(sample_content)
# Out:
# str

# %%
def preprocessing(text):
    # 개행문자 제거
    text =  text.strip('\t\n\r')
    pattern = re.compile(r'\s+')
    text = re.sub(pattern, ' ', text)
    # 특수문자 제거
    # 특수문자나 이모티콘 등은 때로는 의미를 갖기도 하지만 여기에서는 제거했습니다.
    # text = re.sub('[?.,;:|\)*~`’!^\-_+<>@\#$%&-=#}※]', '', text)
    # 한글, 영문, 숫자만 남기고 모두 제거하도록 합니다.
    # text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', ' ', text)
    # 한글, 영문만 남기고 모두 제거하도록 합니다.
    text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', text)
    return text

# %%
import re

sample_content = preprocessing(sample_content)
sample_content[:1000]
# Out:
# 'I call you one time two time three time I Can t wait no more Your Fingers through my hair That s on my mind I know it s been a minute Since you walked right through that door But I still think about you all the time I Don t know I don t know How I m gonna make it out I don t know I don t know Now You got me sayin  Fuck I m lonely I m lonely I m lonely as Fuck come hold me Come hold me come hold me It s been me myself and why Did You go  Did you go  Oh fuck I m lonely I m lonely I m lonely lonely I Yeah I still watch the shows you showed me I still drink that wine But these days it tastes More bitter than sweet hmm And all my friends are way too drunk To save me from my phone So sorry if I say some things I mean I don t know I don t know How I m gonna make it out I don t know I don t know Now you got me sayin  Fuck I m lonely I m lonely I m lonely as Fuck come hold me Come hold me come hold me It s been me myself and why Did you go  Did you go  Oh fuck I m lonely I m lonely I m lonely l'

# %%
word_tokens = tokenize_text(sample_content)
print(word_tokens)
# Out:
# [['I', 'call', 'you', 'one', 'time', 'two', 'time', 'three', 'time', 'I', 'Can', 't', 'wait', 'no', 'more', 'Your', 'Fingers', 'through', 'my', 'hair', 'That', 's', 'on', 'my', 'mind', 'I', 'know', 'it', 's', 'been', 'a', 'minute', 'Since', 'you', 'walked', 'right', 'through', 'that', 'door', 'But', 'I', 'still', 'think', 'about', 'you', 'all', 'the', 'time', 'I', 'Don', 't', 'know', 'I', 'don', 't', 'know', 'How', 'I', 'm', 'gon', 'na', 'make', 'it', 'out', 'I', 'don', 't', 'know', 'I', 'don', 't', 'know', 'Now', 'You', 'got', 'me', 'sayin', 'Fuck', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'as', 'Fuck', 'come', 'hold', 'me', 'Come', 'hold', 'me', 'come', 'hold', 'me', 'It', 's', 'been', 'me', 'myself', 'and', 'why', 'Did', 'You', 'go', 'Did', 'you', 'go', 'Oh', 'fuck', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'lonely', 'I', 'Yeah', 'I', 'still', 'watch', 'the', 'shows', 'you', 'showed', 'me', 'I', 'still', 'drink', 'that', 'wine', 'But', 'these', 'days', 'it', 'tastes', 'More', 'bitter', 'than', 'sweet', 'hmm', 'And', 'all', 'my', 'friends', 'are', 'way', 'too', 'drunk', 'To', 'save', 'me', 'from', 'my', 'phone', 'So', 'sorry', 'if', 'I', 'say', 'some', 'things', 'I', 'mean', 'I', 'don', 't', 'know', 'I', 'don', 't', 'know', 'How', 'I', 'm', 'gon', 'na', 'make', 'it', 'out', 'I', 'don', 't', 'know', 'I', 'don', 't', 'know', 'Now', 'you', 'got', 'me', 'sayin', 'Fuck', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'as', 'Fuck', 'come', 'hold', 'me', 'Come', 'hold', 'me', 'come', 'hold', 'me', 'It', 's', 'been', 'me', 'myself', 'and', 'why', 'Did', 'you', 'go', 'Did', 'you', 'go', 'Oh', 'fuck', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'lonely', 'I', 'Miss', 'those', 'nights', 'When', 'you', 'would', 'come', 'over', 'Spent', 'all', 'night', 'just', 'tryna', 'get', 'closer', 'That', 'was', 'june', 'and', 'now', 'it', 's', 'october', 'I', 'don', 't', 'want', 'don', 't', 'want', 'to', 'get', 'over', 'I', 'miss', 'those', 'nights', 'When', 'you', 'would', 'come', 'over', 'Spent', 'all', 'night', 'just', 'tryna', 'get', 'closer', 'That', 'was', 'june', 'and', 'now', 'it', 's', 'october', 'I', 'don', 't', 'want', 'don', 't', 'want', 'to', 'get', 'over', 'you', 'Oh', 'get', 'over', 'you', 'Fuck', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'as', 'Fuck', 'come', 'hold', 'me', 'Come', 'hold', 'me', 'come', 'hold', 'me', 'It', 's', 'been', 'me', 'myself', 'and', 'why', 'Did', 'you', 'go', 'Did', 'you', 'go', 'Oh', 'fuck', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'I', 'm', 'lonely', 'lonely', 'I', 'I', 'miss', 'those', 'nights', 'When', 'you', 'would', 'come', 'over', 'Yeah', 'Spent', 'all', 'night', 'just', 'tryna', 'get', 'closer', 'That', 'was', 'june', 'and', 'now', 'it', 's', 'october', 'I', 'don', 't', 'want', 'don', 't', 'want', 'to', 'get', 'over', 'I', 'miss', 'those', 'nights', 'When', 'you', 'would', 'come', 'over', 'Spent', 'all', 'night', 'just', 'tryna', 'get', 'closer', 'That', 'was', 'june', 'and', 'now', 'it', 's', 'october', 'I', 'don', 't', 'want', 'don', 't', 'want', 'to', 'get', 'over', 'you', 'Hmm', 'hmm']]

# %%
word_list = pd.Series(word_tokens)
result = word_list.value_counts().head(20)
result
# Out:
# [I, call, you, one, time, two, time, three, time, I, Can, t, wait, no, more, Your, Fingers, through, my, hair, That, s, on, my, mind, I, know, it, s, been, a, minute, Since, you, walked, right, through, that, door, But, I, still, think, about, you, all, the, time, I, Don, t, know, I, don, t, know, How, I, m, gon, na, make, it, out, I, don, t, know, I, don, t, know, Now, You, got, me, sayin, Fuck, I, m, lonely, I, m, lonely, I, m, lonely, as, Fuck, come, hold, me, Come, hold, me, come, hold, me, It, s, ...]    1
# dtype: int64

# %% [markdown]
# ### TF-IDF 기반

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorization 적용하여 학습 데이터셋과 테스트 데이터 셋 변환. 
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(text_lyrics)
X_tfidf_vect = tfidf_vect.transform(text_lyrics)

# %%
X_tfidf_vect
# Out:
# <50x989 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4516 stored elements in Compressed Sparse Row format>

# %%
from scipy import sparse

coo = sparse.coo_matrix(X_tfidf_vect)
coo
# Out:
# <50x989 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4516 stored elements in COOrdinate format>

# %%
topic_word_indexes = X_tfidf_vect.argsort()[::-1]
top_indexes=topic_word_indexes[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-f0959827af7f> in <module>
# ----> 1 topic_word_indexes = X_tfidf_vect.argsort()[::-1]
#       2 top_indexes=topic_word_indexes[:10]
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\base.py in __getattr__(self, attr)
#     686             return self.getnnz()
#     687         else:
# --> 688             raise AttributeError(attr + " not found")
#     689
#     690     def transpose(self, axes=None, copy=False):
#
# AttributeError: argsort not found
